# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/shris/Downloads/bank+marketing/bank/bank-full.csv" , delimiter = ';')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
col = df['campaign'].describe()

# %%
col.is_unique
# Out:
# False

# %%
# Total campaigns available :

# %%
df['campaign'].value_counts()
# Out:
# 1     17544
# 2     12505
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 25       22
# 23       22
# 24       20
# 29       16
# 28       16
# 26       13
# 31       12
# 27       10
# 32        9
# 30        8
# 33        6
# 34        5
# 36        4
# 35        4
# 43        3
# 38        3
# 37        2
# 50        2
# 41        2
# 46        1
# 58        1
# 55        1
# 63        1
# 51        1
# 39        1
# 44        1
# Name: campaign, dtype: int64

# %%
len(set(list(df['campaign'])))
# Out:
# 48

# %%
df[((df['housing'] == 'yes') & (df['loan'] == 'yes'))]
# Out:
#        age           job  marital  education default  balance housing loan  \
# 2       33  entrepreneur  married  secondary      no        2     yes  yes
# 6       28    management   single   tertiary      no      447     yes  yes
# 20      28   blue-collar  married  secondary      no      723     yes  yes
# 22      32   blue-collar   single    primary      no       23     yes  yes
# 24      40       retired  married    primary      no        0     yes  yes
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 45103   33        admin.  married  secondary      no       51     yes  yes
# 45108   36    technician  married   tertiary      no      844     yes  yes
# 45122   40  entrepreneur   single   tertiary      no      262     yes  yes
# 45151   47    management   single   tertiary      no      311     yes  yes
# 45194   59    management  married   tertiary      no      138     yes  yes
#
# ...

# %%
len(df[((df['housing'] == 'yes') & (df['loan'] == 'yes'))])
# Out:
# 4367

# %%
df['age'] > 60
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45206    False
# 45207     True
# 45208     True
# 45209    False
# 45210    False
# Name: age, Length: 45211, dtype: bool

# %%
len(df[df['age'] > 60])
# Out:
# 1188

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df['month'].value_counts()
# Out:
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64

# %%
(df['month'].value_counts()).index[0]
# Out:
# 'may'

# %%
df['contact'].value_counts()
# Out:
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64

# %%
df['poutcome'].value_counts()
# Out:
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64

# %%
df[((df['contact'] == 'cellular') & (df['poutcome'] == 'success'))]
# Out:
#        age            job   marital  education default  balance housing loan  \
# 24239   48         admin.  divorced  secondary      no      295     yes   no
# 24264   49     management   married   tertiary      no       64      no   no
# 24435   42     technician   married   tertiary      no    14282     yes   no
# 24545   46       services  divorced  secondary      no        0      no   no
# 24574   36     management  divorced   tertiary      no     3837     yes   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 45190   32    blue-collar   married  secondary      no      136      no   no
# 45193   28  self-employed    single   tertiary      no      159      no   no
# 45195   68        retired   married  secondary      no     1146      no   no
# 45201   53     management   married   tertiary      no      583      no   no
# 45208   72        retired   married  secondary      no     5715      no   no
#
# ...

# %%
df[((df['contact'] == 'telephone') & (df['poutcome'] == 'success'))]
# Out:
#        age            job   marital  education default  balance housing loan  \
# 24165   30         admin.   married  secondary      no      873     yes   no
# 24506   42     unemployed   married    unknown      no      970     yes   no
# 25962   34         admin.   married   tertiary      no      899     yes   no
# 26069   39     management  divorced   tertiary      no     4692     yes   no
# 27974   41  self-employed    single   tertiary      no     1616      no   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 45078   77        retired   married  secondary      no      820      no   no
# 45112   24        student    single  secondary      no     1234      no   no
# 45140   63   entrepreneur   married  secondary      no     3904      no   no
# 45141   77        unknown   married    unknown      no      397      no   no
# 45166   41     unemployed    single   tertiary      no       79      no   no
#
# ...

# %%
df.groupby(['contact' , 'poutcome']).count()
# Out:
#                       age    job  marital  education  default  balance  \
# contact   poutcome
# cellular  failure    4529   4529     4529       4529     4529     4529
#           other      1637   1637     1637       1637     1637     1637
#           success    1385   1385     1385       1385     1385     1385
#           unknown   21734  21734    21734      21734    21734    21734
# telephone failure     341    341      341        341      341      341
#           other       176    176      176        176      176      176
#           success     114    114      114        114      114      114
#           unknown    2275   2275     2275       2275     2275     2275
# unknown   failure      31     31       31         31       31       31
#           other        27     27       27         27       27       27
#           success      12     12       12         12       12       12
#           unknown   12950  12950    12950      12950    12950    12950
#
# ...

# %%
# cellular  contact is most successful

# %%
# prepare a group of data based on education level :

# %%
l = []
for i in df['education'].unique():
    l.append(pd.DataFrame(df[df['education'] == i]))

# %%
l
# Out:
# [       age           job   marital education default  balance housing loan  \
#  0       58    management   married  tertiary      no     2143     yes   no
#  5       35    management   married  tertiary      no      231     yes   no
#  6       28    management    single  tertiary      no      447     yes  yes
#  7       42  entrepreneur  divorced  tertiary     yes        2     yes   no
#  21      56    management   married  tertiary      no      779     yes   no
#  ...    ...           ...       ...       ...     ...      ...     ...  ...
#  45194   59    management   married  tertiary      no      138     yes  yes
#  45198   37    management   married  tertiary      no     1428      no   no
#  45201   53    management   married  tertiary      no      583      no   no
#  45203   23       student    single  tertiary      no      113      no   no
#  45206   51    technician   married  tertiary      no      825      no   no
#
# ...

# %%
df.groupby('education').count()
# Out:
#              age    job  marital  default  balance  housing   loan  contact  \
# education
# primary     6851   6851     6851     6851     6851     6851   6851     6851
# secondary  23202  23202    23202    23202    23202    23202  23202    23202
# tertiary   13301  13301    13301    13301    13301    13301  13301    13301
# unknown     1857   1857     1857     1857     1857     1857   1857     1857
#
#              day  month  duration  campaign  pdays  previous  poutcome      y
# education
# primary     6851   6851      6851      6851   6851      6851      6851   6851
# secondary  23202  23202     23202     23202  23202     23202     23202  23202
# tertiary   13301  13301     13301     13301  13301     13301     13301  13301
# unknown     1857   1857      1857      1857   1857      1857      1857   1857

# %%
l[0]
# Out:
#        age           job   marital education default  balance housing loan  \
# 0       58    management   married  tertiary      no     2143     yes   no
# 5       35    management   married  tertiary      no      231     yes   no
# 6       28    management    single  tertiary      no      447     yes  yes
# 7       42  entrepreneur  divorced  tertiary     yes        2     yes   no
# 21      56    management   married  tertiary      no      779     yes   no
# ...    ...           ...       ...       ...     ...      ...     ...  ...
# 45194   59    management   married  tertiary      no      138     yes  yes
# 45198   37    management   married  tertiary      no     1428      no   no
# 45201   53    management   married  tertiary      no      583      no   no
# 45203   23       student    single  tertiary      no      113      no   no
# 45206   51    technician   married  tertiary      no      825      no   no
#
# ...

# %%
df1 = l[0]

# %%
df1
# Out:
#        age           job   marital education default  balance housing loan  \
# 0       58    management   married  tertiary      no     2143     yes   no
# 5       35    management   married  tertiary      no      231     yes   no
# 6       28    management    single  tertiary      no      447     yes  yes
# 7       42  entrepreneur  divorced  tertiary     yes        2     yes   no
# 21      56    management   married  tertiary      no      779     yes   no
# ...    ...           ...       ...       ...     ...      ...     ...  ...
# 45194   59    management   married  tertiary      no      138     yes  yes
# 45198   37    management   married  tertiary      no     1428      no   no
# 45201   53    management   married  tertiary      no      583      no   no
# 45203   23       student    single  tertiary      no      113      no   no
# 45206   51    technician   married  tertiary      no      825      no   no
#
# ...

# %%
filename = 'tertiary_edu_bank_data.xlsx'

# %%
df1.to_excel(filename)

# %%
ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 3CFC-44C7
#
#  Directory of C:\Users\shris
#
# 16-10-2023  21:42             2,838  Pandas 1.ipynb
# 01-11-2023  18:00    <DIR>          .
# 31-07-2023  19:27    <DIR>          ..
# 05-08-2023  17:19    <DIR>          .conda
# 05-08-2023  17:08                42 .condarc
# 01-08-2023  10:03    <DIR>          .continuum
# 28-10-2023  18:32    <DIR>          .ipynb_checkpoints
# 02-08-2023  21:28    <DIR>          .ipython
# 03-08-2023  23:23    <DIR>          .jupyter
# 07-08-2023  20:05    <DIR>          .matplotlib
# 26-08-2023  17:15    <DIR>          .spyder-py3
# 01-08-2023  09:39    <DIR>          .vscode
# 01-11-2023  18:00           116,683 Bank - An.ipynb
# 27-08-2023  01:27            41,314 Basic.ipynb
# 20-09-2023  08:06               164 Book1.csv
# 17-09-2023  19:19            51,867 car.data
# 31-07-2023  19:09    <DIR>          Contacts
# 11-10-2023  17:13            47,605 cricinfo.csv
# ...
